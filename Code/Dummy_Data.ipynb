# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_excel(r"F:\Muhs Project\Data Data\Dataset\MUHS_Patient_Data(Dummy).xlsx")

# %%
# df2 = pd.read_excel(r"F:\Muhs Project\Data Data\Dataset\MUHS_Patient_Data(Dummy).xlsx",'Evening_OPD')

# %%
df.shape
# Out:
# (18388, 8)

# %%
df.head(5)
# Out:
#    srno opd_name   time_w   in_Time  Service_time                 date  \
# 0    22  ENT_OPD  Morning  09:00:00             6  2023-09-01 00:00:00
# 1     9      MED  Morning  09:02:00             3  2023-09-01 00:00:00
# 2    93  ENT_OPD  Morning  09:02:00             8  2023-09-01 00:00:00
# 3   117      MED  Morning  09:02:00             3  2023-09-01 00:00:00
# 4   375      MED  Morning  09:03:00             4  2023-09-01 00:00:00
#
#    patient_id           random_name
# 0     4739363          Ehsaan Datta
# 1     2462423        Hiran Banerjee
# 2     1512052  Indranil Chakrabarti
# 3     3428104          Vritika Goda
# 4     1289619          Neysa Khosla

# %%
df.tail()
# Out:
#        srno  opd_name   time_w   in_Time  Service_time        date  \
# 18383  2455  PAED_OPD  Evening  17:52:00             7  30/09/2023
# 18384  2532       MED  Evening  17:53:00             3  30/09/2023
# 18385  2458       MED  Evening  17:55:00             4  30/09/2023
# 18386  2476      SKIN  Evening  17:57:00             4  30/09/2023
# 18387  2485       MED  Evening  17:59:00             3  30/09/2023
#
#        patient_id     random_name
# 18383     8213894  Shayak Warrior
# 18384     6800128      Sahil Anne
# 18385     5551049   Yuvraj Sahota
# 18386     7578329      Rhea Madan
# 18387     7401033  Baiju Choudhry

# %%
df['date'] = pd.to_datetime(df['date'])
df
# Out:
#        srno  opd_name   time_w   in_Time  Service_time       date  patient_id  \
# 0        22   ENT_OPD  Morning  09:00:00             6 2023-09-01     4739363
# 1         9       MED  Morning  09:02:00             3 2023-09-01     2462423
# 2        93   ENT_OPD  Morning  09:02:00             8 2023-09-01     1512052
# 3       117       MED  Morning  09:02:00             3 2023-09-01     3428104
# 4       375       MED  Morning  09:03:00             4 2023-09-01     1289619
# ...     ...       ...      ...       ...           ...        ...         ...
# 18383  2455  PAED_OPD  Evening  17:52:00             7 2023-09-30     8213894
# 18384  2532       MED  Evening  17:53:00             3 2023-09-30     6800128
# 18385  2458       MED  Evening  17:55:00             4 2023-09-30     5551049
# 18386  2476      SKIN  Evening  17:57:00             4 2023-09-30     7578329
# 18387  2485       MED  Evening  17:59:00             3 2023-09-30     7401033
#
#                 random_name
# ...

# %%
df['day'] = df['date'].dt.day_name()
df
# Out:
#        srno  opd_name   time_w   in_Time  Service_time       date  patient_id  \
# 0        22   ENT_OPD  Morning  09:00:00             6 2023-09-01     4739363
# 1         9       MED  Morning  09:02:00             3 2023-09-01     2462423
# 2        93   ENT_OPD  Morning  09:02:00             8 2023-09-01     1512052
# 3       117       MED  Morning  09:02:00             3 2023-09-01     3428104
# 4       375       MED  Morning  09:03:00             4 2023-09-01     1289619
# ...     ...       ...      ...       ...           ...        ...         ...
# 18383  2455  PAED_OPD  Evening  17:52:00             7 2023-09-30     8213894
# 18384  2532       MED  Evening  17:53:00             3 2023-09-30     6800128
# 18385  2458       MED  Evening  17:55:00             4 2023-09-30     5551049
# 18386  2476      SKIN  Evening  17:57:00             4 2023-09-30     7578329
# 18387  2485       MED  Evening  17:59:00             3 2023-09-30     7401033
#
# ...

# %%
# df.to_csv('Dummy_data_BI_ready.csv')
